# %% [markdown]
# Merging ALL csv files

# %%
import glob
import pandas as pd

# use your path
path = r'../Scott/Output'

yelp_files = glob.glob(path + "/*.csv")

list = []

for filename in yelp_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    list.append(df)

frame = pd.concat(list, axis=0, ignore_index=True, sort=False)

# %%
yelp_df = pd.DataFrame(frame)
yelp_df.head()
# Out:
#   Unnamed: 0                      ID                      Name  Zipcode  \
# 0          0  rgE5mVpDI12N_PGbfthxQg  IL Faro Restaurant & Bar  12204.0
# 1          1  LEr0mIvHmNlrCl7VmMV56w              Cafe Madison  12204.0
# 2          2  3D3RFVt0-ACjdOLDHHnKWw                   Risotto  12204.0
# 3          3  XALx5GBpXVZEaQ1e6MoW7A               Tuscan Oven  12204.0
# 4          4  4ToPo-f-SK8vbrDGUjjMeQ  Druthers Brewing Company  12204.0
#
#     Latitude  Longitude Price  Rating  Zip Codes
# 0  42.677236 -73.737267    $$     4.5        NaN
# 1  42.675631 -73.749003    $$     4.0        NaN
# 2  42.674131 -73.749867    $$     4.0        NaN
# 3  42.683140 -73.732371    $$     3.5        NaN
# 4  42.666249 -73.741568    $$     4.0        NaN

# %%
#drop any entries without a zipcode using column =

clean_yelp_df=yelp_df[pd.notnull(yelp_df['Zipcode'])]

clean_yelp_df.head()
# Out:
#   Unnamed: 0                      ID                      Name  Zipcode  \
# 0          0  rgE5mVpDI12N_PGbfthxQg  IL Faro Restaurant & Bar  12204.0
# 1          1  LEr0mIvHmNlrCl7VmMV56w              Cafe Madison  12204.0
# 2          2  3D3RFVt0-ACjdOLDHHnKWw                   Risotto  12204.0
# 3          3  XALx5GBpXVZEaQ1e6MoW7A               Tuscan Oven  12204.0
# 4          4  4ToPo-f-SK8vbrDGUjjMeQ  Druthers Brewing Company  12204.0
#
#     Latitude  Longitude Price  Rating  Zip Codes
# 0  42.677236 -73.737267    $$     4.5        NaN
# 1  42.675631 -73.749003    $$     4.0        NaN
# 2  42.674131 -73.749867    $$     4.0        NaN
# 3  42.683140 -73.732371    $$     3.5        NaN
# 4  42.666249 -73.741568    $$     4.0        NaN

# %%
#convert Zipcodes to an integer then to a string so that we can 

clean_yelp_df["Zipcode"]=clean_yelp_df["Zipcode"].astype(int)

clean_yelp_df["Zipcode"]=clean_yelp_df["Zipcode"].astype(str)

clean_yelp_df.head()

#df.set_index(["Zipcode"])
# Out:
# /Users/rjh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/rjh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Unnamed: 0                      ID                      Name Zipcode  \
# 0          0  rgE5mVpDI12N_PGbfthxQg  IL Faro Restaurant & Bar   12204
# 1          1  LEr0mIvHmNlrCl7VmMV56w              Cafe Madison   12204
# 2          2  3D3RFVt0-ACjdOLDHHnKWw                   Risotto   12204
# 3          3  XALx5GBpXVZEaQ1e6MoW7A               Tuscan Oven   12204
# 4          4  4ToPo-f-SK8vbrDGUjjMeQ  Druthers Brewing Company   12204
#
#     Latitude  Longitude Price  Rating  Zip Codes
# 0  42.677236 -73.737267    $$     4.5        NaN
# 1  42.675631 -73.749003    $$     4.0        NaN
# 2  42.674131 -73.749867    $$     4.0        NaN
# 3  42.683140 -73.732371    $$     3.5        NaN
# 4  42.666249 -73.741568    $$     4.0        NaN

# %%
#save to csv
clean_yelp_df.to_csv("yelpdata.csv")

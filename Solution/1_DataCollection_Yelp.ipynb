# %% [markdown]
# # 1 Data Collection - Yelp
# The Yelp API contains the abilty to search for businesses and filter based on location and different categories. The "Business Search" API is used to collect the data (https://www.yelp.com/developers/documentation/v3/business_search).
#
# First a random list of zipcodes is determined for the study area. Then for each zipcode, the Yelp API is queried. Once for those businesses the have the category of "gluten free" and restaurant; the second query just get records that are "restaurant".
#
# The Yelp business data is then summarized for each zipcode. The end result is two .CSV files:
#
#   * yelpData.csv: Name of the file that contains DataFrame of all data returned from the Yelp API calls
#
#   * summarizedYelpData.csv: Name of the file that contains the Dataframe that summarizes the Yelp data
#
# ## Dependency
# ##### 1 barnum Library
# The barnum python library is used to generate a random list of zip codes.  It is install with the following:
#   'pip install barnum'
#
# ##### 2 secrets.py
# The collection of restaurant data uses the Yelp API that requires a key. This key is stored within the secrets.py that contains a single variable, "yelpKey".

# %%
#-- Import Libraries
import pandas as pd
import os
import math
import barnum
import requests


# Yelp API key in secrets.py; .gitignore prevents the secrets.py from being pushed to GitHub
from secrets import yelpKey


#-- Configuration Settings

#- Common Settings
# Name of the column that contains the zip code information
zipcodeColumnName = "Zipcode"

# Folder that is to contain output of different processing
outputDirectory = "AnalysisData"


#- Random Zipcodes
# Number of zip codes to gather data for; use 100 for analysis and 3 for testing
numRandomZipcodes = 50

# Name of the file that contains the DataFrame of the random zipcodes
randomZipcodesFileName = "randomZipcode.csv"


#- Collect Yelp Datasets
# Yelp search radius; used with API call
yelpSearchRadius = 3000

# TRUE- use the file of the random zipcodes for yelp dataset FALSE- use the DataFrame in memory
useFileForYelpSearch = False

# Name of the file that contains DataFrame of all data returned from the Yelp API calls
yelpDataFileName = "yelpData.csv"

# Name of the file that contains DataFrame of the zipcode and counts return from Yelp API calls
yelpDataSummaryFileName = "YelpSummaryData.csv"

# Name of the file that contains DataFrame for just one zip code
yelpDataZipcodeFileName = "YelpDataZip_"


#- Summarize Yelp Data
# TRUE- use the file of the DataFrame that contains the yelp businesses FASLE- use the DataFrame in memory
useFileForYelpSummarize = True

# Name of the file that contains the Dataframe that summarizes the Yelp data
summarizedYelpFileName = "summarizedYelpData.csv"

# %% [markdown]
# # 1 Create Random Zip Codes
# This step creates a list of the random zip codes within the study area of Southern California. The barnum library is used to generate the random list. The random zip codes are verified to ensure that they are within the study area and then stored to disk.

# %%
#-- Create Random Zipcodes

#- Create List
hasAllZipcodes = False
randomZipcodes = []

while hasAllZipcodes == False:
    theZipCode = barnum.create_city_state_zip()[0]
    numZipCode = int(theZipCode)
    
    if (numZipCode >= 90001) and (numZipCode <= 93005):
        randomZipcodes.append(theZipCode)
        
    if (numRandomZipcodes == len(randomZipcodes)):
        hasAllZipcodes = True 

        
#- Create DataFrame
randomZipcodes_df = pd.DataFrame(randomZipcodes)

randomZipcodes_df.columns = [zipcodeColumnName]


#- Save to Disk
randomZipcodesPath = os.path.join(".", outputDirectory, randomZipcodesFileName)

randomZipcodes_df.to_csv(randomZipcodesPath)


#- Preview Random Zipcodes
randomZipcodes_df.head()
# Out:
#   Zipcode
# 0   90746
# 1   92210
# 2   90210
# 3   92605
# 4   90028

# %% [markdown]
# # 2 Collect Yelp Data
# For each of the random zipcodes the Yelp API is used to collect a single datasets using the Business Search API (https://www.yelp.com/developers/documentation/v3/business_search). The Yelp API is queried two times:
#
# * Yelp filter of "restaurant" and "gluten_free".
# * Yelp filter of only "restaurant"
#
# There is validation to ensure that the business returned from the Yelp API is contained with the zip code provided. Additionally, it was found that some businesses did not have a "price" attribute within the JSON and there is validation to prevent this from stopping the processing.
#
# The yelp data for all the zipcodes is stored within a DataFrame, yelpData_df, and is also exported to a CSV file in: {outputDirectory}/{yelpDataFileName}
#
# Another DataFrame that contains the zipcode with the count of the records found with the two searches is also created.  This DataFrame, yelpDataSummary_df, and exported to a CSV file in: {outputDirectory}/{yelpDataSummaryFileName}
#
# The individual zipcode yelp data is stored within a DataFrame, yelpData_df, and is also exported to CSV file in {outputDirectory}/{yelpDataZipcodeFileName}

# %%
def getDataForZipcode(isGlutenFreeSearch, searchZipCode):
    ''' Searches the Yelp API to get the business that satisfy the filter. Validation to ensure that the 
    response from the Yelp API is successful; when there is a failure the code has try again logic.
    
    Accepts : isGlutenFreeSearcj (bool) TRUE- search for gluten free term FALSE- search just for restaurant
                searchZipCode (str) zip code to search for records within
    
    Returns : (dictionary) contains information of business for the zip code
                ID: (str) Unique Yelp ID for the business
                Name: (str) Name of the business
                Zipcode: (str) Location of the business
                Latitude: (num) coordinate of the business location
                Longitude: (num) coordinate of the business location
                Price: (str) Price level of the business. Value is one of $, $$, $$$, $$$$ and NA
                Rating: (num) Rating for this business (value ranges from 1, 1.5, ... 4.5, 5)
                IsGlutenFree: (num) 1 - used with the gluten free filter 0 not used with gluten free search
                
                Or None when errors encountered with requests
    '''
    
    #- Prepare Search
    # Source Url
    baseYelpUrl = "https://api.yelp.com/v3/businesses/search"

    # API Key passed through header
    headers = {
            'Authorization': 'Bearer %s' % yelpKey,
    }
    
    # Search Term
    searchTerm = 'restaurant'
    
    if (isGlutenFreeSearch == True):
        searchTerm = 'gluten_free,restaurant'
    
    
    # Dictionary stores data
    yelpData = {
        'ID': [],
        'Name': [],
        'Zipcode': [],
        'Latitude': [],
        'Longitude': [],
        'Price' : [],
        'Rating' : [],
        'IsGlutenFree': [],
    }
    
    
    #- Search
    #  API limits 50 records being returned at once; must loop and request offset of results to get all records
    recordLimit = 50
    currentOffset = 0
    hasMoreData = True
    retryCount = 0
    totalCount = 0
    
    while hasMoreData == True:
        
        #- Prepare Parameters
        parameters = {
            'location': searchZipCode,
            'term': searchTerm,
            'limit': recordLimit,
            'offset': currentOffset,
            }
        
        #- Request
        print(f"  Requesting data. Offset: {currentOffset}  Known Total: {totalCount}")
        
        response = requests.request('GET', baseYelpUrl, headers=headers, params=parameters)
        
        
        #- Check Response
        if (response.status_code == requests.codes.ok):
            
            # Reset Retry
            retryCount = 0
            
            
            # Get Json from Response
            responseJson = response.json()
            
            
            # Search Businesses
            for business in responseJson['businesses']:
                
                # Determine Use Business
                useBusiness = checkBusinessForUsage(business, searchZipCode)
                
                if (useBusiness == True):
                    
                    # Populate Dictionary with Business Information
                    yelpData['ID'].append(business['id'])
                    yelpData['Name'].append(business['name'])
                    yelpData['Zipcode'].append(business['location']['zip_code'])
                    
                    yelpData['Latitude'].append(business['coordinates']['latitude'])
                    yelpData['Longitude'].append(business['coordinates']['longitude'])
                    
                    yelpData['Price'].append(getPriceForBusiness(business))
                    yelpData['Rating'].append(business['rating'])
                    
                    # Update search type
                    if (isGlutenFreeSearch == True):
                        yelpData['IsGlutenFree'].append(1)
                    else:
                        yelpData['IsGlutenFree'].append(0)
         
            #- Prepare for Next search
            # API only supports 50 records at a time; must query with offset
            currentOffset = (currentOffset + recordLimit)
            
            totalCount = responseJson['total']
            
            if (currentOffset > responseJson['total']):
                print(f"Collected all data. Current Offset: {currentOffset}  Total: {responseJson['total']}")
                hasMoreData = False
        
        else:
            #- Error with request
            retryCount += 1
            print(f"Response Error for data: {response.status_code}  Retry Count: {retryCount}")     
            
            #- Attempt to retry request
            if (retryCount == 4):
                print("Error getting data for zipcode")
                return None
    
                  
    #- Metadata on Data
    print(f"Total businesses found: {len(yelpData['ID'])}  Search Term: {searchTerm}")
               
          
    #- Return data from function
    return yelpData

# %%
def checkBusinessForUsage(businessInfo, searchZipcode):
    ''' Determines if the business can be used in the Analysis
    
    Accepts : businessInfo (dictionary) contains the metadata for individual business 
                searchZipCode (str) zip code searching for data within
    
    Return : bool TRUE- business meets critera, able to use FALSE- unable to use business
    '''
    
    #- Check Within Search Zipcode
    businessZipCode = businessInfo['location']['zip_code']
    
    if (businessZipCode != searchZipcode):
        return False
    
    
    return True

# %%
def getPriceForBusiness(businessInfo):
    ''' Gets the price for a business; not all businesses contain this property within the JSON;
    when not found just uses NA.
    
    Accepts : businessInfo (dictionary) metadata on an individual business
    
    Returns : (num) value from price tag
    '''
    try:
        
        return businessInfo['price']
    
    except:
        return 'NA'

# %%
#-- Collect Yelp Datasets

#- Get Random Zipcodes
if (useFileForYelpSearch == True):
    randomZipcodesPath = os.path.join(".", outputDirectory, randomZipcodesFileName)
    
    randomZipcodes_df = pd.read_csv(randomZipcodesPath)

else:
    if (randomZipcodes_df is None):
        raise Exception("Unable to collect Yelp dataset; missing reference to randomZipcodes_df")

        
#- Prepare Variables
zipcodeSummary = {
    zipcodeColumnName: [],
    'HasApiFailure': [],
    'Count_GlutenFree': [],
    'Count_Restaurant': []
}

yelpData_df = None
hasFirstYelpData = True
counter = 0


#- Collect Data
for index, row in randomZipcodes_df.iterrows():
    
    #- Get Zipcode
    searchZipcode = str(row[0])
    
    
    #- Message
    counter += 1
    print(f"-> Search -> {searchZipcode}  -> {counter} of {randomZipcodes_df.shape[0]}")
    
    
    #- Get Data from Yelp: Gluten Free Search
    yelpDataForZipcode = getDataForZipcode(True, searchZipcode)
    
    
    #- Get Data for Yelp: Restaurant
    yelpDataRestaurantForZipcode = getDataForZipcode(False, searchZipcode)
    
    
    #- Create DataFrames; check success getting data from endpoint
    if not (yelpDataForZipcode is None) and not (yelpDataRestaurantForZipcode is None):
        
        #- Gluten Free
        # Create DataFrame
        yelpDataGlutenFreeForZipcode_df = pd.DataFrame(yelpDataForZipcode)
    
        # Determine number of records
        countYelpDataForZipcode = yelpDataGlutenFreeForZipcode_df.shape[0]
    
 
        #- All Restaurants
        # Create DataFrame
        yelpDataAllForZipcode_df = pd.DataFrame(yelpDataRestaurantForZipcode)
        
        # Determine number of records
        countYelpDataSummaryForZipcode = yelpDataAllForZipcode_df.shape[0]
        
        
        #- Combine and Save Data for Zipcode
        # Merge Gluten Free & Restuarnts for Zipcode
        yelpDataForZipcode_df = pd.concat([yelpDataGlutenFreeForZipcode_df, yelpDataAllForZipcode_df])
        
        # Save to Disk
        yelpDataZipcodePath = os.path.join(".", outputDirectory, f"{yelpDataZipcodeFileName}{searchZipcode}.csv")
        
        yelpDataForZipcode_df.to_csv(yelpDataZipcodePath)                                  
        
        print(" Exported data for zipcode to disk..")
        
                                           
        #- Create Single DataFrame
        if (hasFirstYelpData == True):
            hasFirstYelpData = False
            yelpData_df = yelpDataForZipcode_df
    
        else:
            yelpData_df = pd.concat([yelpData_df, yelpDataForZipcode_df])
        
        
        #- Update Summary
        zipcodeSummary[zipcodeColumnName].append(searchZipcode)
        zipcodeSummary['HasApiFailure'].append(0)
        
        zipcodeSummary['Count_GlutenFree'].append(countYelpDataForZipcode)
        zipcodeSummary['Count_Restaurant'].append(countYelpDataSummaryForZipcode)  
        
    else:
        
        #- Error with at least one search filter; do not use zipcode
        zipcodeSummary[zipcodeColumnName].append(searchZipcode)
        zipcodeSummary['HasApiFailure'].append(1)
        
        zipcodeSummary['Count_GlutenFree'].append(0)
        zipcodeSummary['Count_Restaurant'].append(0) 
    

#- Message
print("<--<")
print("Completed getting data from Yelp API")
    
    
#- Export: Yelp Data
yelpDataFilePath = os.path.join('.', outputDirectory, yelpDataFileName)

yelpData_df.to_csv(yelpDataFilePath)


#- Export: Yelp Summary Data
yelpDataSummaryFilePath = os.path.join('.', outputDirectory, yelpDataSummaryFileName)

yelpDataSummary_df = pd.DataFrame(zipcodeSummary)

yelpDataSummary_df.to_csv(yelpDataSummaryFileName)


#- Completed Message
print("Completed export of data")
# Out:
# -> Search -> 90746  -> 1 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 358
#   Requesting data. Offset: 100  Known Total: 358
#   Requesting data. Offset: 150  Known Total: 358
#   Requesting data. Offset: 200  Known Total: 358
#   Requesting data. Offset: 250  Known Total: 358
#   Requesting data. Offset: 300  Known Total: 358
#   Requesting data. Offset: 350  Known Total: 358
# Collected all data. Current Offset: 400  Total: 358
# Total businesses found: 11  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 2600
#   Requesting data. Offset: 100  Known Total: 2600
#   Requesting data. Offset: 150  Known Total: 2600
#   Requesting data. Offset: 200  Known Total: 2600
#   Requesting data. Offset: 250  Known Total: 2600
#   Requesting data. Offset: 300  Known Total: 2600
#   Requesting data. Offset: 350  Known Total: 2600
#   Requesting data. Offset: 400  Known Total: 2600
#   Requesting data. Offset: 450  Known Total: 2600
#   Requesting data. Offset: 500  Known Total: 2600
#   Requesting data. Offset: 550  Known Total: 2600
#   Requesting data. Offset: 600  Known Total: 2600
#   Requesting data. Offset: 650  Known Total: 2600
#   Requesting data. Offset: 700  Known Total: 2600
#   Requesting data. Offset: 750  Known Total: 2600
#   Requesting data. Offset: 800  Known Total: 2600
#   Requesting data. Offset: 850  Known Total: 2600
#   Requesting data. Offset: 900  Known Total: 2600
#   Requesting data. Offset: 950  Known Total: 2600
#   Requesting data. Offset: 1000  Known Total: 2600
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 2600
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 2600
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 2600
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 92210  -> 2 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 161
#   Requesting data. Offset: 100  Known Total: 161
#   Requesting data. Offset: 150  Known Total: 161
# Collected all data. Current Offset: 200  Total: 161
# Total businesses found: 9  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 432
#   Requesting data. Offset: 100  Known Total: 432
#   Requesting data. Offset: 150  Known Total: 432
#   Requesting data. Offset: 200  Known Total: 432
#   Requesting data. Offset: 250  Known Total: 432
#   Requesting data. Offset: 300  Known Total: 432
#   Requesting data. Offset: 350  Known Total: 432
#   Requesting data. Offset: 400  Known Total: 432
# Collected all data. Current Offset: 450  Total: 432
# Total businesses found: 20  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90210  -> 3 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 2000
#   Requesting data. Offset: 100  Known Total: 2000
#   Requesting data. Offset: 150  Known Total: 2000
#   Requesting data. Offset: 200  Known Total: 2000
#   Requesting data. Offset: 250  Known Total: 2000
#   Requesting data. Offset: 300  Known Total: 2000
#   Requesting data. Offset: 350  Known Total: 2000
#   Requesting data. Offset: 400  Known Total: 2000
#   Requesting data. Offset: 450  Known Total: 2000
#   Requesting data. Offset: 500  Known Total: 2000
#   Requesting data. Offset: 550  Known Total: 2000
#   Requesting data. Offset: 600  Known Total: 2000
#   Requesting data. Offset: 650  Known Total: 2000
#   Requesting data. Offset: 700  Known Total: 2000
#   Requesting data. Offset: 750  Known Total: 2000
#   Requesting data. Offset: 800  Known Total: 2000
#   Requesting data. Offset: 850  Known Total: 2000
#   Requesting data. Offset: 900  Known Total: 2000
#   Requesting data. Offset: 950  Known Total: 2000
#   Requesting data. Offset: 1000  Known Total: 2000
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 2000
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 2000
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 2000
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 4000
#   Requesting data. Offset: 100  Known Total: 4000
#   Requesting data. Offset: 150  Known Total: 4000
#   Requesting data. Offset: 200  Known Total: 4000
#   Requesting data. Offset: 250  Known Total: 4000
#   Requesting data. Offset: 300  Known Total: 4000
#   Requesting data. Offset: 350  Known Total: 4000
#   Requesting data. Offset: 400  Known Total: 4000
#   Requesting data. Offset: 450  Known Total: 4000
#   Requesting data. Offset: 500  Known Total: 4000
#   Requesting data. Offset: 550  Known Total: 4000
#   Requesting data. Offset: 600  Known Total: 4000
#   Requesting data. Offset: 650  Known Total: 4000
#   Requesting data. Offset: 700  Known Total: 4000
#   Requesting data. Offset: 750  Known Total: 4000
#   Requesting data. Offset: 800  Known Total: 4000
#   Requesting data. Offset: 850  Known Total: 4000
#   Requesting data. Offset: 900  Known Total: 4000
#   Requesting data. Offset: 950  Known Total: 4000
#   Requesting data. Offset: 1000  Known Total: 4000
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 4000
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 4000
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 4000
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 92605  -> 4 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 8
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 12
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90028  -> 5 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 899
#   Requesting data. Offset: 100  Known Total: 899
#   Requesting data. Offset: 150  Known Total: 899
#   Requesting data. Offset: 200  Known Total: 899
#   Requesting data. Offset: 250  Known Total: 899
#   Requesting data. Offset: 300  Known Total: 899
#   Requesting data. Offset: 350  Known Total: 899
#   Requesting data. Offset: 400  Known Total: 899
#   Requesting data. Offset: 450  Known Total: 899
#   Requesting data. Offset: 500  Known Total: 899
#   Requesting data. Offset: 550  Known Total: 899
#   Requesting data. Offset: 600  Known Total: 899
#   Requesting data. Offset: 650  Known Total: 899
#   Requesting data. Offset: 700  Known Total: 899
#   Requesting data. Offset: 750  Known Total: 899
#   Requesting data. Offset: 800  Known Total: 899
#   Requesting data. Offset: 850  Known Total: 899
# Collected all data. Current Offset: 900  Total: 899
# Total businesses found: 135  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 727
#   Requesting data. Offset: 100  Known Total: 727
#   Requesting data. Offset: 150  Known Total: 727
#   Requesting data. Offset: 200  Known Total: 727
#   Requesting data. Offset: 250  Known Total: 727
#   Requesting data. Offset: 300  Known Total: 727
#   Requesting data. Offset: 350  Known Total: 727
#   Requesting data. Offset: 400  Known Total: 727
#   Requesting data. Offset: 450  Known Total: 727
#   Requesting data. Offset: 500  Known Total: 727
#   Requesting data. Offset: 550  Known Total: 727
#   Requesting data. Offset: 600  Known Total: 727
#   Requesting data. Offset: 650  Known Total: 727
#   Requesting data. Offset: 700  Known Total: 727
# Collected all data. Current Offset: 750  Total: 727
# Total businesses found: 287  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 91110  -> 6 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 347
#   Requesting data. Offset: 100  Known Total: 347
#   Requesting data. Offset: 150  Known Total: 347
#   Requesting data. Offset: 200  Known Total: 347
#   Requesting data. Offset: 250  Known Total: 347
#   Requesting data. Offset: 300  Known Total: 347
# Collected all data. Current Offset: 350  Total: 347
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 6
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90264  -> 7 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 16
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 17
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 92401  -> 8 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 46
# Total businesses found: 1  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 389
#   Requesting data. Offset: 100  Known Total: 389
#   Requesting data. Offset: 150  Known Total: 389
#   Requesting data. Offset: 200  Known Total: 389
#   Requesting data. Offset: 250  Known Total: 389
#   Requesting data. Offset: 300  Known Total: 389
#   Requesting data. Offset: 350  Known Total: 389
# Collected all data. Current Offset: 400  Total: 389
# Total businesses found: 20  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 92517  -> 9 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 12
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 8
# Total businesses found: 1  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 92084  -> 10 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 692
#   Requesting data. Offset: 100  Known Total: 692
#   Requesting data. Offset: 150  Known Total: 692
#   Requesting data. Offset: 200  Known Total: 692
#   Requesting data. Offset: 250  Known Total: 692
#   Requesting data. Offset: 300  Known Total: 692
#   Requesting data. Offset: 350  Known Total: 692
#   Requesting data. Offset: 400  Known Total: 692
#   Requesting data. Offset: 450  Known Total: 692
#   Requesting data. Offset: 500  Known Total: 692
#   Requesting data. Offset: 550  Known Total: 692
#   Requesting data. Offset: 600  Known Total: 692
#   Requesting data. Offset: 650  Known Total: 692
# Collected all data. Current Offset: 700  Total: 692
# Total businesses found: 29  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1700
#   Requesting data. Offset: 100  Known Total: 1700
#   Requesting data. Offset: 150  Known Total: 1700
#   Requesting data. Offset: 200  Known Total: 1700
#   Requesting data. Offset: 250  Known Total: 1700
#   Requesting data. Offset: 300  Known Total: 1700
#   Requesting data. Offset: 350  Known Total: 1700
#   Requesting data. Offset: 400  Known Total: 1700
#   Requesting data. Offset: 450  Known Total: 1700
#   Requesting data. Offset: 500  Known Total: 1700
#   Requesting data. Offset: 550  Known Total: 1700
#   Requesting data. Offset: 600  Known Total: 1700
#   Requesting data. Offset: 650  Known Total: 1700
#   Requesting data. Offset: 700  Known Total: 1700
#   Requesting data. Offset: 750  Known Total: 1700
#   Requesting data. Offset: 800  Known Total: 1700
#   Requesting data. Offset: 850  Known Total: 1700
#   Requesting data. Offset: 900  Known Total: 1700
#   Requesting data. Offset: 950  Known Total: 1700
#   Requesting data. Offset: 1000  Known Total: 1700
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1700
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1700
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1700
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 92660  -> 11 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 763
#   Requesting data. Offset: 100  Known Total: 763
#   Requesting data. Offset: 150  Known Total: 763
#   Requesting data. Offset: 200  Known Total: 763
#   Requesting data. Offset: 250  Known Total: 763
#   Requesting data. Offset: 300  Known Total: 763
#   Requesting data. Offset: 350  Known Total: 763
#   Requesting data. Offset: 400  Known Total: 763
#   Requesting data. Offset: 450  Known Total: 763
#   Requesting data. Offset: 500  Known Total: 763
#   Requesting data. Offset: 550  Known Total: 763
#   Requesting data. Offset: 600  Known Total: 763
#   Requesting data. Offset: 650  Known Total: 763
#   Requesting data. Offset: 700  Known Total: 763
#   Requesting data. Offset: 750  Known Total: 763
# Collected all data. Current Offset: 800  Total: 763
# Total businesses found: 77  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1700
#   Requesting data. Offset: 100  Known Total: 1700
#   Requesting data. Offset: 150  Known Total: 1700
#   Requesting data. Offset: 200  Known Total: 1700
#   Requesting data. Offset: 250  Known Total: 1700
#   Requesting data. Offset: 300  Known Total: 1700
#   Requesting data. Offset: 350  Known Total: 1700
#   Requesting data. Offset: 400  Known Total: 1700
#   Requesting data. Offset: 450  Known Total: 1700
#   Requesting data. Offset: 500  Known Total: 1700
#   Requesting data. Offset: 550  Known Total: 1700
#   Requesting data. Offset: 600  Known Total: 1700
#   Requesting data. Offset: 650  Known Total: 1700
#   Requesting data. Offset: 700  Known Total: 1700
#   Requesting data. Offset: 750  Known Total: 1700
#   Requesting data. Offset: 800  Known Total: 1700
#   Requesting data. Offset: 850  Known Total: 1700
#   Requesting data. Offset: 900  Known Total: 1700
#   Requesting data. Offset: 950  Known Total: 1700
#   Requesting data. Offset: 1000  Known Total: 1700
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1700
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1700
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1700
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 92037  -> 12 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1900
#   Requesting data. Offset: 100  Known Total: 1900
#   Requesting data. Offset: 150  Known Total: 1900
#   Requesting data. Offset: 200  Known Total: 1900
#   Requesting data. Offset: 250  Known Total: 1900
#   Requesting data. Offset: 300  Known Total: 1900
#   Requesting data. Offset: 350  Known Total: 1900
#   Requesting data. Offset: 400  Known Total: 1900
#   Requesting data. Offset: 450  Known Total: 1900
#   Requesting data. Offset: 500  Known Total: 1900
#   Requesting data. Offset: 550  Known Total: 1900
#   Requesting data. Offset: 600  Known Total: 1900
#   Requesting data. Offset: 650  Known Total: 1900
#   Requesting data. Offset: 700  Known Total: 1900
#   Requesting data. Offset: 750  Known Total: 1900
#   Requesting data. Offset: 800  Known Total: 1900
#   Requesting data. Offset: 850  Known Total: 1900
#   Requesting data. Offset: 900  Known Total: 1900
#   Requesting data. Offset: 950  Known Total: 1900
#   Requesting data. Offset: 1000  Known Total: 1900
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1900
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1900
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1900
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1200
#   Requesting data. Offset: 100  Known Total: 1200
#   Requesting data. Offset: 150  Known Total: 1200
#   Requesting data. Offset: 200  Known Total: 1200
#   Requesting data. Offset: 250  Known Total: 1200
#   Requesting data. Offset: 300  Known Total: 1200
#   Requesting data. Offset: 350  Known Total: 1200
#   Requesting data. Offset: 400  Known Total: 1200
#   Requesting data. Offset: 450  Known Total: 1200
#   Requesting data. Offset: 500  Known Total: 1200
#   Requesting data. Offset: 550  Known Total: 1200
#   Requesting data. Offset: 600  Known Total: 1200
#   Requesting data. Offset: 650  Known Total: 1200
#   Requesting data. Offset: 700  Known Total: 1200
#   Requesting data. Offset: 750  Known Total: 1200
#   Requesting data. Offset: 800  Known Total: 1200
#   Requesting data. Offset: 850  Known Total: 1200
#   Requesting data. Offset: 900  Known Total: 1200
#   Requesting data. Offset: 950  Known Total: 1200
#   Requesting data. Offset: 1000  Known Total: 1200
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1200
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1200
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1200
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 92585  -> 13 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 43
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 209
#   Requesting data. Offset: 100  Known Total: 209
#   Requesting data. Offset: 150  Known Total: 209
#   Requesting data. Offset: 200  Known Total: 209
# Collected all data. Current Offset: 250  Total: 209
# Total businesses found: 8  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 91436  -> 14 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 592
#   Requesting data. Offset: 100  Known Total: 592
#   Requesting data. Offset: 150  Known Total: 592
#   Requesting data. Offset: 200  Known Total: 592
#   Requesting data. Offset: 250  Known Total: 592
#   Requesting data. Offset: 300  Known Total: 592
#   Requesting data. Offset: 350  Known Total: 592
#   Requesting data. Offset: 400  Known Total: 592
#   Requesting data. Offset: 450  Known Total: 592
#   Requesting data. Offset: 500  Known Total: 592
#   Requesting data. Offset: 550  Known Total: 592
# Collected all data. Current Offset: 600  Total: 592
# Total businesses found: 33  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 589
#   Requesting data. Offset: 100  Known Total: 589
#   Requesting data. Offset: 150  Known Total: 589
#   Requesting data. Offset: 200  Known Total: 589
#   Requesting data. Offset: 250  Known Total: 589
#   Requesting data. Offset: 300  Known Total: 590
#   Requesting data. Offset: 350  Known Total: 590
#   Requesting data. Offset: 400  Known Total: 590
#   Requesting data. Offset: 450  Known Total: 590
#   Requesting data. Offset: 500  Known Total: 589
#   Requesting data. Offset: 550  Known Total: 590
# Collected all data. Current Offset: 600  Total: 590
# Total businesses found: 70  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 91765  -> 15 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1000
#   Requesting data. Offset: 100  Known Total: 1000
#   Requesting data. Offset: 150  Known Total: 1000
#   Requesting data. Offset: 200  Known Total: 1000
#   Requesting data. Offset: 250  Known Total: 1000
#   Requesting data. Offset: 300  Known Total: 1000
#   Requesting data. Offset: 350  Known Total: 1000
#   Requesting data. Offset: 400  Known Total: 1000
#   Requesting data. Offset: 450  Known Total: 1000
#   Requesting data. Offset: 500  Known Total: 1000
#   Requesting data. Offset: 550  Known Total: 1000
#   Requesting data. Offset: 600  Known Total: 1000
#   Requesting data. Offset: 650  Known Total: 1000
#   Requesting data. Offset: 700  Known Total: 1000
#   Requesting data. Offset: 750  Known Total: 1000
#   Requesting data. Offset: 800  Known Total: 1000
#   Requesting data. Offset: 850  Known Total: 1000
#   Requesting data. Offset: 900  Known Total: 1000
#   Requesting data. Offset: 950  Known Total: 1000
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 5000
#   Requesting data. Offset: 100  Known Total: 5000
#   Requesting data. Offset: 150  Known Total: 5000
#   Requesting data. Offset: 200  Known Total: 5000
#   Requesting data. Offset: 250  Known Total: 5000
#   Requesting data. Offset: 300  Known Total: 5000
#   Requesting data. Offset: 350  Known Total: 5000
#   Requesting data. Offset: 400  Known Total: 5000
#   Requesting data. Offset: 450  Known Total: 5000
#   Requesting data. Offset: 500  Known Total: 5000
#   Requesting data. Offset: 550  Known Total: 5000
#   Requesting data. Offset: 600  Known Total: 5000
#   Requesting data. Offset: 650  Known Total: 5000
#   Requesting data. Offset: 700  Known Total: 5000
#   Requesting data. Offset: 750  Known Total: 5000
#   Requesting data. Offset: 800  Known Total: 5000
#   Requesting data. Offset: 850  Known Total: 5000
#   Requesting data. Offset: 900  Known Total: 5000
#   Requesting data. Offset: 950  Known Total: 5000
#   Requesting data. Offset: 1000  Known Total: 5000
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 5000
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 5000
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 5000
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 91046  -> 16 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 37
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 81
# Collected all data. Current Offset: 100  Total: 81
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 91724  -> 17 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 252
#   Requesting data. Offset: 100  Known Total: 252
#   Requesting data. Offset: 150  Known Total: 252
#   Requesting data. Offset: 200  Known Total: 252
#   Requesting data. Offset: 250  Known Total: 252
# Collected all data. Current Offset: 300  Total: 252
# Total businesses found: 2  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1400
#   Requesting data. Offset: 100  Known Total: 1400
#   Requesting data. Offset: 150  Known Total: 1400
#   Requesting data. Offset: 200  Known Total: 1400
#   Requesting data. Offset: 250  Known Total: 1400
#   Requesting data. Offset: 300  Known Total: 1400
#   Requesting data. Offset: 350  Known Total: 1400
#   Requesting data. Offset: 400  Known Total: 1400
#   Requesting data. Offset: 450  Known Total: 1400
#   Requesting data. Offset: 500  Known Total: 1400
#   Requesting data. Offset: 550  Known Total: 1400
#   Requesting data. Offset: 600  Known Total: 1400
#   Requesting data. Offset: 650  Known Total: 1400
#   Requesting data. Offset: 700  Known Total: 1400
#   Requesting data. Offset: 750  Known Total: 1400
#   Requesting data. Offset: 800  Known Total: 1400
#   Requesting data. Offset: 850  Known Total: 1400
#   Requesting data. Offset: 900  Known Total: 1400
#   Requesting data. Offset: 950  Known Total: 1400
#   Requesting data. Offset: 1000  Known Total: 1400
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1400
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1400
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1400
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 91358  -> 18 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 12
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 13
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 91001  -> 19 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 549
#   Requesting data. Offset: 100  Known Total: 549
#   Requesting data. Offset: 150  Known Total: 549
#   Requesting data. Offset: 200  Known Total: 549
#   Requesting data. Offset: 250  Known Total: 549
#   Requesting data. Offset: 300  Known Total: 549
#   Requesting data. Offset: 350  Known Total: 549
#   Requesting data. Offset: 400  Known Total: 549
#   Requesting data. Offset: 450  Known Total: 549
#   Requesting data. Offset: 500  Known Total: 549
# Collected all data. Current Offset: 550  Total: 549
# Total businesses found: 7  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1300
#   Requesting data. Offset: 100  Known Total: 1300
#   Requesting data. Offset: 150  Known Total: 1300
#   Requesting data. Offset: 200  Known Total: 1300
#   Requesting data. Offset: 250  Known Total: 1300
#   Requesting data. Offset: 300  Known Total: 1300
#   Requesting data. Offset: 350  Known Total: 1300
#   Requesting data. Offset: 400  Known Total: 1300
#   Requesting data. Offset: 450  Known Total: 1300
#   Requesting data. Offset: 500  Known Total: 1300
#   Requesting data. Offset: 550  Known Total: 1300
#   Requesting data. Offset: 600  Known Total: 1300
#   Requesting data. Offset: 650  Known Total: 1300
#   Requesting data. Offset: 700  Known Total: 1300
#   Requesting data. Offset: 750  Known Total: 1300
#   Requesting data. Offset: 800  Known Total: 1300
#   Requesting data. Offset: 850  Known Total: 1300
#   Requesting data. Offset: 900  Known Total: 1300
#   Requesting data. Offset: 950  Known Total: 1300
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 92704  -> 20 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1000
#   Requesting data. Offset: 100  Known Total: 1000
#   Requesting data. Offset: 150  Known Total: 1000
#   Requesting data. Offset: 200  Known Total: 1000
#   Requesting data. Offset: 250  Known Total: 1000
#   Requesting data. Offset: 300  Known Total: 1000
#   Requesting data. Offset: 350  Known Total: 1000
#   Requesting data. Offset: 400  Known Total: 1000
#   Requesting data. Offset: 450  Known Total: 1000
#   Requesting data. Offset: 500  Known Total: 1000
#   Requesting data. Offset: 550  Known Total: 1000
#   Requesting data. Offset: 600  Known Total: 1000
#   Requesting data. Offset: 650  Known Total: 1000
#   Requesting data. Offset: 700  Known Total: 1000
#   Requesting data. Offset: 750  Known Total: 1000
#   Requesting data. Offset: 800  Known Total: 1000
#   Requesting data. Offset: 850  Known Total: 1000
#   Requesting data. Offset: 900  Known Total: 1000
#   Requesting data. Offset: 950  Known Total: 1000
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 3500
#   Requesting data. Offset: 100  Known Total: 3500
#   Requesting data. Offset: 150  Known Total: 3500
#   Requesting data. Offset: 200  Known Total: 3500
#   Requesting data. Offset: 250  Known Total: 3500
#   Requesting data. Offset: 300  Known Total: 3500
#   Requesting data. Offset: 350  Known Total: 3500
#   Requesting data. Offset: 400  Known Total: 3500
#   Requesting data. Offset: 450  Known Total: 3500
#   Requesting data. Offset: 500  Known Total: 3500
#   Requesting data. Offset: 550  Known Total: 3500
#   Requesting data. Offset: 600  Known Total: 3500
#   Requesting data. Offset: 650  Known Total: 3500
#   Requesting data. Offset: 700  Known Total: 3500
#   Requesting data. Offset: 750  Known Total: 3500
#   Requesting data. Offset: 800  Known Total: 3500
#   Requesting data. Offset: 850  Known Total: 3500
#   Requesting data. Offset: 900  Known Total: 3500
#   Requesting data. Offset: 950  Known Total: 3500
#   Requesting data. Offset: 1000  Known Total: 3500
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 3500
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 3500
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 3500
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 92364  -> 21 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 186
#   Requesting data. Offset: 100  Known Total: 186
#   Requesting data. Offset: 150  Known Total: 186
# Collected all data. Current Offset: 200  Total: 186
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 25
# Total businesses found: 1  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 92036  -> 22 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 3100
#   Requesting data. Offset: 100  Known Total: 3100
#   Requesting data. Offset: 150  Known Total: 3100
#   Requesting data. Offset: 200  Known Total: 3100
#   Requesting data. Offset: 250  Known Total: 3100
#   Requesting data. Offset: 300  Known Total: 3100
#   Requesting data. Offset: 350  Known Total: 3100
#   Requesting data. Offset: 400  Known Total: 3100
#   Requesting data. Offset: 450  Known Total: 3100
#   Requesting data. Offset: 500  Known Total: 3100
#   Requesting data. Offset: 550  Known Total: 3100
#   Requesting data. Offset: 600  Known Total: 3100
#   Requesting data. Offset: 650  Known Total: 3100
#   Requesting data. Offset: 700  Known Total: 3100
#   Requesting data. Offset: 750  Known Total: 3100
#   Requesting data. Offset: 800  Known Total: 3100
#   Requesting data. Offset: 850  Known Total: 3100
#   Requesting data. Offset: 900  Known Total: 3100
#   Requesting data. Offset: 950  Known Total: 3100
#   Requesting data. Offset: 1000  Known Total: 3100
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 3100
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 3100
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 3100
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 181
#   Requesting data. Offset: 100  Known Total: 181
#   Requesting data. Offset: 150  Known Total: 181
# Collected all data. Current Offset: 200  Total: 181
# Total businesses found: 18  Search Term: restaurant
# -> Search -> 93001  -> 23 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 898
#   Requesting data. Offset: 100  Known Total: 898
#   Requesting data. Offset: 150  Known Total: 898
#   Requesting data. Offset: 200  Known Total: 898
#   Requesting data. Offset: 250  Known Total: 898
#   Requesting data. Offset: 300  Known Total: 898
#   Requesting data. Offset: 350  Known Total: 898
#   Requesting data. Offset: 400  Known Total: 898
#   Requesting data. Offset: 450  Known Total: 898
#   Requesting data. Offset: 500  Known Total: 898
#   Requesting data. Offset: 550  Known Total: 898
#   Requesting data. Offset: 600  Known Total: 898
#   Requesting data. Offset: 650  Known Total: 898
#   Requesting data. Offset: 700  Known Total: 898
#   Requesting data. Offset: 750  Known Total: 898
#   Requesting data. Offset: 800  Known Total: 898
#   Requesting data. Offset: 850  Known Total: 898
# Collected all data. Current Offset: 900  Total: 898
# Total businesses found: 59  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1400
#   Requesting data. Offset: 100  Known Total: 1400
#   Requesting data. Offset: 150  Known Total: 1400
#   Requesting data. Offset: 200  Known Total: 1400
#   Requesting data. Offset: 250  Known Total: 1400
#   Requesting data. Offset: 300  Known Total: 1400
#   Requesting data. Offset: 350  Known Total: 1400
#   Requesting data. Offset: 400  Known Total: 1400
#   Requesting data. Offset: 450  Known Total: 1400
#   Requesting data. Offset: 500  Known Total: 1400
#   Requesting data. Offset: 550  Known Total: 1400
#   Requesting data. Offset: 600  Known Total: 1400
#   Requesting data. Offset: 650  Known Total: 1400
#   Requesting data. Offset: 700  Known Total: 1400
#   Requesting data. Offset: 750  Known Total: 1400
#   Requesting data. Offset: 800  Known Total: 1400
#   Requesting data. Offset: 850  Known Total: 1400
#   Requesting data. Offset: 900  Known Total: 1400
#   Requesting data. Offset: 950  Known Total: 1400
#   Requesting data. Offset: 1000  Known Total: 1400
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1400
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1400
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1400
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 91126  -> 24 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 67
# Collected all data. Current Offset: 100  Total: 67
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 121
#   Requesting data. Offset: 100  Known Total: 121
# Collected all data. Current Offset: 150  Total: 121
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90069  -> 25 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 794
#   Requesting data. Offset: 100  Known Total: 794
#   Requesting data. Offset: 150  Known Total: 794
#   Requesting data. Offset: 200  Known Total: 794
#   Requesting data. Offset: 250  Known Total: 794
#   Requesting data. Offset: 300  Known Total: 794
#   Requesting data. Offset: 350  Known Total: 794
#   Requesting data. Offset: 400  Known Total: 794
#   Requesting data. Offset: 450  Known Total: 794
#   Requesting data. Offset: 500  Known Total: 794
#   Requesting data. Offset: 550  Known Total: 794
#   Requesting data. Offset: 600  Known Total: 794
#   Requesting data. Offset: 650  Known Total: 794
#   Requesting data. Offset: 700  Known Total: 794
#   Requesting data. Offset: 750  Known Total: 794
# Collected all data. Current Offset: 800  Total: 794
# Total businesses found: 103  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1500
#   Requesting data. Offset: 100  Known Total: 1500
#   Requesting data. Offset: 150  Known Total: 1500
#   Requesting data. Offset: 200  Known Total: 1500
#   Requesting data. Offset: 250  Known Total: 1500
#   Requesting data. Offset: 300  Known Total: 1500
#   Requesting data. Offset: 350  Known Total: 1500
#   Requesting data. Offset: 400  Known Total: 1500
#   Requesting data. Offset: 450  Known Total: 1500
#   Requesting data. Offset: 500  Known Total: 1500
#   Requesting data. Offset: 550  Known Total: 1500
#   Requesting data. Offset: 600  Known Total: 1500
#   Requesting data. Offset: 650  Known Total: 1500
#   Requesting data. Offset: 700  Known Total: 1500
#   Requesting data. Offset: 750  Known Total: 1500
#   Requesting data. Offset: 800  Known Total: 1500
#   Requesting data. Offset: 850  Known Total: 1500
#   Requesting data. Offset: 900  Known Total: 1500
#   Requesting data. Offset: 950  Known Total: 1500
#   Requesting data. Offset: 1000  Known Total: 1500
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1500
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1500
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1500
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 91767  -> 26 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 295
#   Requesting data. Offset: 100  Known Total: 295
#   Requesting data. Offset: 150  Known Total: 295
#   Requesting data. Offset: 200  Known Total: 295
#   Requesting data. Offset: 250  Known Total: 295
# Collected all data. Current Offset: 300  Total: 295
# Total businesses found: 8  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1300
#   Requesting data. Offset: 100  Known Total: 1300
#   Requesting data. Offset: 150  Known Total: 1300
#   Requesting data. Offset: 200  Known Total: 1300
#   Requesting data. Offset: 250  Known Total: 1300
#   Requesting data. Offset: 300  Known Total: 1300
#   Requesting data. Offset: 350  Known Total: 1300
#   Requesting data. Offset: 400  Known Total: 1300
#   Requesting data. Offset: 450  Known Total: 1300
#   Requesting data. Offset: 500  Known Total: 1300
#   Requesting data. Offset: 550  Known Total: 1300
#   Requesting data. Offset: 600  Known Total: 1300
#   Requesting data. Offset: 650  Known Total: 1300
#   Requesting data. Offset: 700  Known Total: 1300
#   Requesting data. Offset: 750  Known Total: 1300
#   Requesting data. Offset: 800  Known Total: 1300
#   Requesting data. Offset: 850  Known Total: 1300
#   Requesting data. Offset: 900  Known Total: 1300
#   Requesting data. Offset: 950  Known Total: 1300
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 92385  -> 27 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 29
# Total businesses found: 1  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 185
#   Requesting data. Offset: 100  Known Total: 185
#   Requesting data. Offset: 150  Known Total: 185
# Collected all data. Current Offset: 200  Total: 185
# Total businesses found: 4  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 92061  -> 28 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1000
#   Requesting data. Offset: 100  Known Total: 1000
#   Requesting data. Offset: 150  Known Total: 1000
#   Requesting data. Offset: 200  Known Total: 1000
#   Requesting data. Offset: 250  Known Total: 1000
#   Requesting data. Offset: 300  Known Total: 1000
#   Requesting data. Offset: 350  Known Total: 1000
#   Requesting data. Offset: 400  Known Total: 1000
#   Requesting data. Offset: 450  Known Total: 1000
#   Requesting data. Offset: 500  Known Total: 1000
#   Requesting data. Offset: 550  Known Total: 1000
#   Requesting data. Offset: 600  Known Total: 1000
#   Requesting data. Offset: 650  Known Total: 1000
#   Requesting data. Offset: 700  Known Total: 1000
#   Requesting data. Offset: 750  Known Total: 1000
#   Requesting data. Offset: 800  Known Total: 1000
#   Requesting data. Offset: 850  Known Total: 1000
#   Requesting data. Offset: 900  Known Total: 1000
#   Requesting data. Offset: 950  Known Total: 1000
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 41
# Total businesses found: 7  Search Term: restaurant
# -> Search -> 92105  -> 29 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1000
#   Requesting data. Offset: 100  Known Total: 1000
#   Requesting data. Offset: 150  Known Total: 1000
#   Requesting data. Offset: 200  Known Total: 1000
#   Requesting data. Offset: 250  Known Total: 1000
#   Requesting data. Offset: 300  Known Total: 1000
#   Requesting data. Offset: 350  Known Total: 1000
#   Requesting data. Offset: 400  Known Total: 1000
#   Requesting data. Offset: 450  Known Total: 1000
#   Requesting data. Offset: 500  Known Total: 1000
#   Requesting data. Offset: 550  Known Total: 1000
#   Requesting data. Offset: 600  Known Total: 1000
#   Requesting data. Offset: 650  Known Total: 1000
#   Requesting data. Offset: 700  Known Total: 1000
#   Requesting data. Offset: 750  Known Total: 1000
#   Requesting data. Offset: 800  Known Total: 1000
#   Requesting data. Offset: 850  Known Total: 1000
#   Requesting data. Offset: 900  Known Total: 1000
#   Requesting data. Offset: 950  Known Total: 1000
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1000
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 711
#   Requesting data. Offset: 100  Known Total: 711
#   Requesting data. Offset: 150  Known Total: 711
#   Requesting data. Offset: 200  Known Total: 711
#   Requesting data. Offset: 250  Known Total: 711
#   Requesting data. Offset: 300  Known Total: 711
#   Requesting data. Offset: 350  Known Total: 711
#   Requesting data. Offset: 400  Known Total: 711
#   Requesting data. Offset: 450  Known Total: 711
#   Requesting data. Offset: 500  Known Total: 711
#   Requesting data. Offset: 550  Known Total: 711
#   Requesting data. Offset: 600  Known Total: 711
#   Requesting data. Offset: 650  Known Total: 711
#   Requesting data. Offset: 700  Known Total: 711
# Collected all data. Current Offset: 750  Total: 711
# Total businesses found: 85  Search Term: restaurant
# -> Search -> 92391  -> 30 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 20
# Total businesses found: 1  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 48
# Total businesses found: 2  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 91749  -> 31 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 31
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 35
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 92163  -> 32 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 19
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 16
# Total businesses found: 1  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 92270  -> 33 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 310
#   Requesting data. Offset: 100  Known Total: 310
#   Requesting data. Offset: 150  Known Total: 310
#   Requesting data. Offset: 200  Known Total: 310
#   Requesting data. Offset: 250  Known Total: 310
#   Requesting data. Offset: 300  Known Total: 310
# Collected all data. Current Offset: 350  Total: 310
# Total businesses found: 35  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 873
#   Requesting data. Offset: 100  Known Total: 873
#   Requesting data. Offset: 150  Known Total: 873
#   Requesting data. Offset: 200  Known Total: 873
#   Requesting data. Offset: 250  Known Total: 873
#   Requesting data. Offset: 300  Known Total: 873
#   Requesting data. Offset: 350  Known Total: 873
#   Requesting data. Offset: 400  Known Total: 873
#   Requesting data. Offset: 450  Known Total: 873
#   Requesting data. Offset: 500  Known Total: 873
#   Requesting data. Offset: 550  Known Total: 873
#   Requesting data. Offset: 600  Known Total: 873
#   Requesting data. Offset: 650  Known Total: 873
#   Requesting data. Offset: 700  Known Total: 873
#   Requesting data. Offset: 750  Known Total: 873
#   Requesting data. Offset: 800  Known Total: 873
#   Requesting data. Offset: 850  Known Total: 873
# Collected all data. Current Offset: 900  Total: 873
# Total businesses found: 72  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 92616  -> 34 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 16
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 7
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 92158  -> 35 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 173
#   Requesting data. Offset: 100  Known Total: 173
#   Requesting data. Offset: 150  Known Total: 173
# Collected all data. Current Offset: 200  Total: 173
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 23
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90263  -> 36 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 28
# Total businesses found: 1  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 36
# Total businesses found: 2  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90835  -> 37 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 68
# Collected all data. Current Offset: 100  Total: 68
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 10
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 91602  -> 38 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 434
#   Requesting data. Offset: 100  Known Total: 434
#   Requesting data. Offset: 150  Known Total: 434
#   Requesting data. Offset: 200  Known Total: 434
#   Requesting data. Offset: 250  Known Total: 434
#   Requesting data. Offset: 300  Known Total: 434
#   Requesting data. Offset: 350  Known Total: 434
#   Requesting data. Offset: 400  Known Total: 434
# Collected all data. Current Offset: 450  Total: 434
# Total businesses found: 36  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 472
#   Requesting data. Offset: 100  Known Total: 472
#   Requesting data. Offset: 150  Known Total: 472
#   Requesting data. Offset: 200  Known Total: 472
#   Requesting data. Offset: 250  Known Total: 472
#   Requesting data. Offset: 300  Known Total: 472
#   Requesting data. Offset: 350  Known Total: 472
#   Requesting data. Offset: 400  Known Total: 472
#   Requesting data. Offset: 450  Known Total: 472
# Collected all data. Current Offset: 500  Total: 472
# Total businesses found: 58  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90301  -> 39 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 203
#   Requesting data. Offset: 100  Known Total: 203
#   Requesting data. Offset: 150  Known Total: 203
#   Requesting data. Offset: 200  Known Total: 203
# Collected all data. Current Offset: 250  Total: 203
# Total businesses found: 8  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 904
#   Requesting data. Offset: 100  Known Total: 904
#   Requesting data. Offset: 150  Known Total: 904
#   Requesting data. Offset: 200  Known Total: 904
#   Requesting data. Offset: 250  Known Total: 904
#   Requesting data. Offset: 300  Known Total: 904
#   Requesting data. Offset: 350  Known Total: 904
#   Requesting data. Offset: 400  Known Total: 904
#   Requesting data. Offset: 450  Known Total: 904
#   Requesting data. Offset: 500  Known Total: 904
#   Requesting data. Offset: 550  Known Total: 904
#   Requesting data. Offset: 600  Known Total: 904
#   Requesting data. Offset: 650  Known Total: 904
#   Requesting data. Offset: 700  Known Total: 904
#   Requesting data. Offset: 750  Known Total: 904
#   Requesting data. Offset: 800  Known Total: 904
#   Requesting data. Offset: 850  Known Total: 904
#   Requesting data. Offset: 900  Known Total: 904
# Collected all data. Current Offset: 950  Total: 904
# Total businesses found: 90  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90846  -> 40 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 74
# Collected all data. Current Offset: 100  Total: 74
# Total businesses found: 2  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 27
# Total businesses found: 3  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 93003  -> 41 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 271
#   Requesting data. Offset: 100  Known Total: 271
#   Requesting data. Offset: 150  Known Total: 271
#   Requesting data. Offset: 200  Known Total: 271
#   Requesting data. Offset: 250  Known Total: 271
# Collected all data. Current Offset: 300  Total: 271
# Total businesses found: 55  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 973
#   Requesting data. Offset: 100  Known Total: 973
#   Requesting data. Offset: 150  Known Total: 973
#   Requesting data. Offset: 200  Known Total: 973
#   Requesting data. Offset: 250  Known Total: 973
#   Requesting data. Offset: 300  Known Total: 973
#   Requesting data. Offset: 350  Known Total: 973
#   Requesting data. Offset: 400  Known Total: 973
#   Requesting data. Offset: 450  Known Total: 973
#   Requesting data. Offset: 500  Known Total: 973
#   Requesting data. Offset: 550  Known Total: 973
#   Requesting data. Offset: 600  Known Total: 973
#   Requesting data. Offset: 650  Known Total: 973
#   Requesting data. Offset: 700  Known Total: 973
#   Requesting data. Offset: 750  Known Total: 973
#   Requesting data. Offset: 800  Known Total: 973
#   Requesting data. Offset: 850  Known Total: 973
#   Requesting data. Offset: 900  Known Total: 973
#   Requesting data. Offset: 950  Known Total: 973
# Collected all data. Current Offset: 1000  Total: 973
# Total businesses found: 152  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 91031  -> 42 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 5
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 8
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 91118  -> 43 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 62
# Collected all data. Current Offset: 100  Total: 62
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 5
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90067  -> 44 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 271
#   Requesting data. Offset: 100  Known Total: 271
#   Requesting data. Offset: 150  Known Total: 271
#   Requesting data. Offset: 200  Known Total: 271
#   Requesting data. Offset: 250  Known Total: 271
# Collected all data. Current Offset: 300  Total: 271
# Total businesses found: 28  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 136
#   Requesting data. Offset: 100  Known Total: 136
# Collected all data. Current Offset: 150  Total: 136
# Total businesses found: 80  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90671  -> 45 of 50
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 10
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
# Collected all data. Current Offset: 50  Total: 25
# Total businesses found: 0  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90270  -> 46 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 94
# Collected all data. Current Offset: 100  Total: 94
# Total businesses found: 0  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 976
#   Requesting data. Offset: 100  Known Total: 976
#   Requesting data. Offset: 150  Known Total: 976
#   Requesting data. Offset: 200  Known Total: 976
#   Requesting data. Offset: 250  Known Total: 976
#   Requesting data. Offset: 300  Known Total: 976
#   Requesting data. Offset: 350  Known Total: 976
#   Requesting data. Offset: 400  Known Total: 976
#   Requesting data. Offset: 450  Known Total: 976
#   Requesting data. Offset: 500  Known Total: 976
#   Requesting data. Offset: 550  Known Total: 976
#   Requesting data. Offset: 600  Known Total: 976
#   Requesting data. Offset: 650  Known Total: 976
#   Requesting data. Offset: 700  Known Total: 976
#   Requesting data. Offset: 750  Known Total: 976
#   Requesting data. Offset: 800  Known Total: 976
#   Requesting data. Offset: 850  Known Total: 976
#   Requesting data. Offset: 900  Known Total: 976
#   Requesting data. Offset: 950  Known Total: 976
# Collected all data. Current Offset: 1000  Total: 976
# Total businesses found: 60  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 92407  -> 47 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 906
#   Requesting data. Offset: 100  Known Total: 906
#   Requesting data. Offset: 150  Known Total: 906
#   Requesting data. Offset: 200  Known Total: 906
#   Requesting data. Offset: 250  Known Total: 906
#   Requesting data. Offset: 300  Known Total: 906
#   Requesting data. Offset: 350  Known Total: 906
#   Requesting data. Offset: 400  Known Total: 906
#   Requesting data. Offset: 450  Known Total: 906
#   Requesting data. Offset: 500  Known Total: 906
#   Requesting data. Offset: 550  Known Total: 906
#   Requesting data. Offset: 600  Known Total: 906
#   Requesting data. Offset: 650  Known Total: 906
#   Requesting data. Offset: 700  Known Total: 906
#   Requesting data. Offset: 750  Known Total: 906
#   Requesting data. Offset: 800  Known Total: 906
#   Requesting data. Offset: 850  Known Total: 906
#   Requesting data. Offset: 900  Known Total: 906
# Collected all data. Current Offset: 950  Total: 906
# Total businesses found: 10  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 249
#   Requesting data. Offset: 100  Known Total: 249
#   Requesting data. Offset: 150  Known Total: 249
#   Requesting data. Offset: 200  Known Total: 249
# Collected all data. Current Offset: 250  Total: 249
# Total businesses found: 66  Search Term: restaurant
#  Exported data for zipcode to disk..
# -> Search -> 90277  -> 48 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 529
#   Requesting data. Offset: 100  Known Total: 529
#   Requesting data. Offset: 150  Known Total: 529
#   Requesting data. Offset: 200  Known Total: 529
#   Requesting data. Offset: 250  Known Total: 529
#   Requesting data. Offset: 300  Known Total: 529
#   Requesting data. Offset: 350  Known Total: 529
#   Requesting data. Offset: 400  Known Total: 529
#   Requesting data. Offset: 450  Known Total: 529
#   Requesting data. Offset: 500  Known Total: 529
# Collected all data. Current Offset: 550  Total: 529
# Total businesses found: 75  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1800
#   Requesting data. Offset: 100  Known Total: 1800
#   Requesting data. Offset: 150  Known Total: 1800
#   Requesting data. Offset: 200  Known Total: 1800
#   Requesting data. Offset: 250  Known Total: 1800
#   Requesting data. Offset: 300  Known Total: 1800
#   Requesting data. Offset: 350  Known Total: 1800
#   Requesting data. Offset: 400  Known Total: 1800
#   Requesting data. Offset: 450  Known Total: 1800
#   Requesting data. Offset: 500  Known Total: 1800
#   Requesting data. Offset: 550  Known Total: 1800
#   Requesting data. Offset: 600  Known Total: 1800
#   Requesting data. Offset: 650  Known Total: 1800
#   Requesting data. Offset: 700  Known Total: 1800
#   Requesting data. Offset: 750  Known Total: 1800
#   Requesting data. Offset: 800  Known Total: 1800
#   Requesting data. Offset: 850  Known Total: 1800
#   Requesting data. Offset: 900  Known Total: 1800
#   Requesting data. Offset: 950  Known Total: 1800
#   Requesting data. Offset: 1000  Known Total: 1800
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1800
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1800
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1800
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 91902  -> 49 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 190
#   Requesting data. Offset: 100  Known Total: 190
#   Requesting data. Offset: 150  Known Total: 190
# Collected all data. Current Offset: 200  Total: 190
# Total businesses found: 7  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 1300
#   Requesting data. Offset: 100  Known Total: 1300
#   Requesting data. Offset: 150  Known Total: 1300
#   Requesting data. Offset: 200  Known Total: 1300
#   Requesting data. Offset: 250  Known Total: 1300
#   Requesting data. Offset: 300  Known Total: 1300
#   Requesting data. Offset: 350  Known Total: 1300
#   Requesting data. Offset: 400  Known Total: 1300
#   Requesting data. Offset: 450  Known Total: 1300
#   Requesting data. Offset: 500  Known Total: 1300
#   Requesting data. Offset: 550  Known Total: 1300
#   Requesting data. Offset: 600  Known Total: 1300
#   Requesting data. Offset: 650  Known Total: 1300
#   Requesting data. Offset: 700  Known Total: 1300
#   Requesting data. Offset: 750  Known Total: 1300
#   Requesting data. Offset: 800  Known Total: 1300
#   Requesting data. Offset: 850  Known Total: 1300
#   Requesting data. Offset: 900  Known Total: 1300
#   Requesting data. Offset: 950  Known Total: 1300
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 1
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 2
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 3
#   Requesting data. Offset: 1000  Known Total: 1300
# Response Error for data: 400  Retry Count: 4
# Error getting data for zipcode
# -> Search -> 92373  -> 50 of 50
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 595
#   Requesting data. Offset: 100  Known Total: 595
#   Requesting data. Offset: 150  Known Total: 595
#   Requesting data. Offset: 200  Known Total: 595
#   Requesting data. Offset: 250  Known Total: 595
#   Requesting data. Offset: 300  Known Total: 595
#   Requesting data. Offset: 350  Known Total: 595
#   Requesting data. Offset: 400  Known Total: 595
#   Requesting data. Offset: 450  Known Total: 595
#   Requesting data. Offset: 500  Known Total: 595
#   Requesting data. Offset: 550  Known Total: 595
# Collected all data. Current Offset: 600  Total: 595
# Total businesses found: 40  Search Term: gluten_free,restaurant
#   Requesting data. Offset: 0  Known Total: 0
#   Requesting data. Offset: 50  Known Total: 571
#   Requesting data. Offset: 100  Known Total: 571
#   Requesting data. Offset: 150  Known Total: 571
#   Requesting data. Offset: 200  Known Total: 571
#   Requesting data. Offset: 250  Known Total: 571
#   Requesting data. Offset: 300  Known Total: 571
#   Requesting data. Offset: 350  Known Total: 571
#   Requesting data. Offset: 400  Known Total: 571
#   Requesting data. Offset: 450  Known Total: 571
#   Requesting data. Offset: 500  Known Total: 571
#   Requesting data. Offset: 550  Known Total: 571
# Collected all data. Current Offset: 600  Total: 571
# Total businesses found: 100  Search Term: restaurant
#  Exported data for zipcode to disk..
# <--<
# Completed getting data from Yelp API
# Completed export of data

# %%
#-- Preview Yelp Data
print(yelpData_df.shape)

yelpData_df.head()
# Out:
# (1492, 8)
#                        ID                                     Name Zipcode  \
# 0  Pw1-_aGws_Hc6-_u8clsHQ                                 The Nest   92210
# 1  A-M0cPJnjjzzeGBecScPKw                                  Eureka!   92210
# 2  1ZKbcWcvThf2E-Fb8pqEvw                         Vue Grille & Bar   92210
# 3  3RbkcqU38_WvWDUVvKjwPQ  Hyatt Regency Indian Wells Resort & Spa   92210
# 4  PNgbVkNt6JEUh5IZLDWUUA                              Cafe Italia   92210
#
#     Latitude   Longitude Price  Rating  IsGlutenFree
# 0  33.721360 -116.358840    $$     4.0           1.0
# 1  33.720920 -116.356821    $$     4.0           1.0
# 2  33.724492 -116.329666    $$     4.5           1.0
# 3  33.724518 -116.331203   $$$     4.0           1.0
# 4  33.720386 -116.358901    $$     4.0           1.0

# %%
#-- Preview Yelp Summary Data
print(yelpDataSummary_df.shape)

yelpDataSummary_df.head()
# Out:
# (50, 4)
#   Zipcode  HasApiFailure  Count_GlutenFree  Count_Restaurant
# 0   90746              1                 0                 0
# 1   92210              0                 9                20
# 2   90210              1                 0                 0
# 3   92605              0                 0                 0
# 4   90028              0               135               287

# %% [markdown]
# # 3 Summarize Yelp Data
# For each zipcode found within the sample dataset, summarize the number of business found, the menu and standard deviation for the price and rating.  This summarization is done for both those business that satisfied the "Gluten Free/Restaurant" filter and the "Restaurant" filter.
#
# A new DataFrame is created, summarizedYelpData_df, and it is also saved to disk.

# %%
def summarizeYelpDataForZipcode(subset_df, searchPrefix, summarizeResult):
    ''' Summarizes the Yelp data based on the DataFrame provided
    
    Accepts : subset_df (DataFrame) records for the zipcode and filter
                searchPrefix (str) prefix used with column names; "GF_" or "ALL_"
                summarizedResults (dictionary) contains summarized data
                
    Returns : summarizedResults (dictionary) append information 
                'Zipcode' (str) name of the zipcode
                'GF_Total' (num) total number of businesses
                'GF_Price_1' (num) total with price of '$'
                'GF_Price_2' (num) total with price of '$$'
                'GF_Price_3' (num) total with price of '$$$'
                'GF_Price_4' (num) total with price of '$$$$'
                'GF_Price_0' (num) total with price of 'NA'
                'GF_Rating_10' (num) total with range of 1.0
                'GF_Rating_15' (num) total with range of 1.5
                'GF_Rating_20' (num) total with range of 2.0
                'GF_Rating_25' (num) total with range of 2.5
                'GF_Rating_30' (num) total with range of 3.0
                'GF_Rating_35' (num) total with range of 3.5
                'GF_Rating_40' (num) total with range of 4.0
                'GF_Rating_45' (num) total with range of 4.5
                'GF_Rating_50' (num) total with range of 5.0
                'GF_Price_Mean' (num) average for price
                'GF_Price_Std' (num) standard deviation for price
                'GF_Rating_Mean' (num) average for rating
                'GF_Rating_Std' (num) standard deviation for rating
                'ALL_Total' (num) total number of businesses
                'ALL_Price_1' (num) total with price of '$'
                'ALL_Price_2' (num) total with price of '$$'
                'ALL_Price_3' (num) total with price of '$$$'
                'ALL_Price_4' (num) total with price of '$$$$'
                'ALL_Price_0' (num) total with price of 'NA'
                'ALL_Rating_10' (num) total with range of 1.0
                'ALL_Rating_15' (num) total with range of 1.5
                'ALL_Rating_20' (num) total with range of 2.0
                'ALL_Rating_25' (num) total with range of 2.5
                'ALL_Rating_30' (num) total with range of 3.0
                'ALL_Rating_35' (num) total with range of 3.5
                'ALL_Rating_40' (num) total with range of 4.0
                'ALL_Rating_45' (num) total with range of 4.5
                'ALL_Rating_50' (num) total with range of 5.0
                'ALL_Price_Mean' (num) average for price
                'ALL_Price_Std' (num) standard deviation for price
                'ALL_Rating_Mean' (num) average for rating
                'ALL_Rating_Std' (num) standard deviation for rating
    '''
    
    #- Total
    summarizeResult[f'{searchPrefix}Total'].append(subset_df.shape[0])
    

    #- Price
    summarizeResult[f'{searchPrefix}Price_1'].append(subset_df[subset_df['Price'] == '$'].shape[0])
    summarizeResult[f'{searchPrefix}Price_2'].append(subset_df[subset_df['Price'] == '$$'].shape[0])
    summarizeResult[f'{searchPrefix}Price_3'].append(subset_df[subset_df['Price'] == '$$$'].shape[0])
    summarizeResult[f'{searchPrefix}Price_4'].append(subset_df[subset_df['Price'] == '$$$$'].shape[0])
    summarizeResult[f'{searchPrefix}Price_0'].append(subset_df[subset_df['Price'] == 'NA'].shape[0])


    #- Rating
    summarizeResult[f'{searchPrefix}Rating_10'].append(subset_df[subset_df['Rating'] == 1.0].shape[0])
    summarizeResult[f'{searchPrefix}Rating_15'].append(subset_df[subset_df['Rating'] == 1.5].shape[0])
    summarizeResult[f'{searchPrefix}Rating_20'].append(subset_df[subset_df['Rating'] == 2.0].shape[0])
    summarizeResult[f'{searchPrefix}Rating_25'].append(subset_df[subset_df['Rating'] == 2.5].shape[0])
    summarizeResult[f'{searchPrefix}Rating_30'].append(subset_df[subset_df['Rating'] == 3.0].shape[0])
    summarizeResult[f'{searchPrefix}Rating_35'].append(subset_df[subset_df['Rating'] == 3.5].shape[0])
    summarizeResult[f'{searchPrefix}Rating_40'].append(subset_df[subset_df['Rating'] == 4.0].shape[0])
    summarizeResult[f'{searchPrefix}Rating_45'].append(subset_df[subset_df['Rating'] == 4.5].shape[0])
    summarizeResult[f'{searchPrefix}Rating_50'].append(subset_df[subset_df['Rating'] == 5.0].shape[0])


    #- Averages
    summarizeResult[f'{searchPrefix}Price_Mean'].append(subset_df['PriceNum'].mean())
    summarizeResult[f'{searchPrefix}Rating_Mean'].append(subset_df['Rating'].mean())


    #- Standard Deviation
    summarizeResult[f'{searchPrefix}Price_Std'].append(subset_df['PriceNum'].std())
    summarizeResult[f'{searchPrefix}Rating_Std'].append(subset_df['Rating'].std())
    
    
    
    return summarizeResult

# %%
def calculatePrice(row):
    ''' Converts the Yelp text of dollar signs into numeric value
    
    Accepts : row individual row from DataFrame; has "Price" column 
    
    Returns : (num) numeric value that is converted from text value
    '''
    
    value = 0.0
    
    if (row['Price'] == '$'):
        value = 1
        
    elif (row['Price'] == '$$'):
        value = 2
        
    elif (row['Price'] == '$$$'):
        value = 3
        
    elif (row['Price'] == '$$$$'):
        value = 4
        
    else:
        value = math.nan
        
    
    return value

# %%
def getZipcodeYelpDataFromFiles():
    ''' Gets the Yelp data that is stored on disk; one file that contains a DataFrame for each
    zipcode
    
    Returns : (DataFrame) contains Yelp data from all of the files found in the output direct
    '''
    
    #- Message
    print("Getting Yelp Data from output folder...")
    
    
    #-- Files in Output Folder
    outputPath = os.path.join(".", outputDirectory)

    files = os.listdir(outputPath)
    
    
    #-- Load Files
    counter = 0
    yelpData_df = None
    hasFirstYelpData = False
    
    for file in files:
        
        #- Check File Name
        if (file.startswith(yelpDataZipcodeFileName) == True):
            
            counter += 1
            
            
            #- Get DataFrame
            filePath = os.path.join('.', outputDirectory, file)
            
            zipCodeYelpData_df = pd.read_csv(filePath)
            
            
            
            #- Merge
            if (hasFirstYelpData == False):
                # First DataFrame, just assign variable
                hasFirstYelpData = True
                
                yelpData_df = zipCodeYelpData_df
                
            else:
                # Merge DataFrames
                yelpData_df = pd.concat([zipCodeYelpData_df, yelpData_df])
                
        
            #- Message
            print(f"Yelp Data... Records: {zipCodeYelpData_df.shape[0]} Counter: {counter}  {file}")
    
    
    return yelpData_df

# %%
#-- Summarize Data Based on Zipcode

#- Get Yelp Data
if (useFileForYelpSummarize == True):
    
    print("Using files on disk to summarize")
    
    # Yelp Business DataFrame
    yelpData_df = getZipcodeYelpDataFromFiles()
    
    
    # Yelp Zipcode Summary DataFrame
    yelpDataSummaryFilePath = os.path.join('.', outputDirectory, yelpDataSummaryFileName)
    
    yelpDataSummary_df = pd.read_csv(yelpDataSummaryFilePath)
    
else:
    if (yelpData_df is None) or (yelpDataSummary_df is None):
        raise Exception("Unable to collect Yelp dataset; missing reference to yelpDataSummary_df or yelpData_df")

  
#- Prepare DataFrame: Numeric Price
# Converts text of different number of $ to numeric value to allow calculations
yelpData_df['PriceNum'] = yelpData_df.apply(lambda row: calculatePrice(row), axis=1)


#- Create Results Container
# Container is to be converted into DataFrame
summarizedResults = {
    zipcodeColumnName: [],
    'GF_Total' : [],
    'GF_Price_1': [],
    'GF_Price_2': [],
    'GF_Price_3': [],
    'GF_Price_4': [],
    'GF_Price_0': [],
    'GF_Rating_10': [],
    'GF_Rating_15': [],
    'GF_Rating_20': [],
    'GF_Rating_25': [],
    'GF_Rating_30': [],
    'GF_Rating_35': [],
    'GF_Rating_40': [],
    'GF_Rating_45': [],
    'GF_Rating_50': [],
    'GF_Price_Mean': [],
    'GF_Rating_Mean': [],
    'GF_Price_Std': [],
    'GF_Rating_Std': [],
    'ALL_Total' : [],
    'ALL_Price_1': [],
    'ALL_Price_2': [],
    'ALL_Price_3': [],
    'ALL_Price_4': [],
    'ALL_Price_0': [],
    'ALL_Rating_10': [],
    'ALL_Rating_15': [],
    'ALL_Rating_20': [],
    'ALL_Rating_25': [],
    'ALL_Rating_30': [],
    'ALL_Rating_35': [],
    'ALL_Rating_40': [],
    'ALL_Rating_45': [],
    'ALL_Rating_50': [],
    'ALL_Price_Mean': [],
    'ALL_Rating_Mean': [],
    'ALL_Price_Std': [],
    'ALL_Rating_Std': [],
    }


#- Message
print(" ")
print("Start summary of Yelp data...")


#- Group by Zipcode
zipcodeYelpData_GroupBy = yelpData_df.groupby(zipcodeColumnName)


#- Summarize for each Zipcode
for groupName, groupedYelpData_df in zipcodeYelpData_GroupBy:
    
    # Zipcode
    summarizedResults[zipcodeColumnName].append(groupName)
    
    
    # Filter: Gluten Free
    subset_df = groupedYelpData_df.loc[(groupedYelpData_df['IsGlutenFree'] == 1)]
    
    summarizedResults = summarizeYelpDataForZipcode(subset_df, "GF_", summarizedResults)
    
    
    # Filter: Restaurants
    subset_df = groupedYelpData_df.loc[(groupedYelpData_df['IsGlutenFree'] == 0)]
    
    summarizedResults = summarizeYelpDataForZipcode(subset_df, "ALL_", summarizedResults)
    

    
#- Create DataFrame
summarizedYelpData_df = pd.DataFrame(summarizedResults)


#- Save to Disk
summarizedYelpPath = os.path.join(".", outputDirectory, summarizedYelpFileName)

summarizedYelpData_df.to_csv(summarizedYelpPath)


print(f"Completed summarizing the data  {summarizedYelpPath}")
# Out:
# Using files on disk to summarize
# Getting Yelp Data from output folder...
# Yelp Data... Records: 0 Counter: 1  YelpDataZip_92393.csv
# Yelp Data... Records: 96 Counter: 2  YelpDataZip_91103.csv
# Yelp Data... Records: 2 Counter: 3  YelpDataZip_92350.csv
# Yelp Data... Records: 2 Counter: 4  YelpDataZip_91329.csv
# Yelp Data... Records: 0 Counter: 5  YelpDataZip_91507.csv
# Yelp Data... Records: 94 Counter: 6  YelpDataZip_90744.csv
# Yelp Data... Records: 0 Counter: 7  YelpDataZip_92153.csv
# Yelp Data... Records: 0 Counter: 8  YelpDataZip_92609.csv
# Yelp Data... Records: 19 Counter: 9  YelpDataZip_90222.csv
# Yelp Data... Records: 0 Counter: 10  YelpDataZip_92186.csv
# Yelp Data... Records: 90 Counter: 11  YelpDataZip_91316.csv
# Yelp Data... Records: 2 Counter: 12  YelpDataZip_92233.csv
# Yelp Data... Records: 0 Counter: 13  YelpDataZip_92232.csv
# Yelp Data... Records: 5 Counter: 14  YelpDataZip_91934.csv
# Yelp Data... Records: 1 Counter: 15  YelpDataZip_90633.csv
# Yelp Data... Records: 150 Counter: 16  YelpDataZip_90035.csv
# Yelp Data... Records: 5 Counter: 17  YelpDataZip_90747.csv
# Yelp Data... Records: 1 Counter: 18  YelpDataZip_92178.csv
# Yelp Data... Records: 0 Counter: 19  YelpDataZip_92193.csv
# Yelp Data... Records: 0 Counter: 20  YelpDataZip_92811.csv
# Yelp Data... Records: 0 Counter: 21  YelpDataZip_90223.csv
# Yelp Data... Records: 195 Counter: 22  YelpDataZip_91101.csv
# Yelp Data... Records: 5 Counter: 23  YelpDataZip_92385.csv
# Yelp Data... Records: 3 Counter: 24  YelpDataZip_92391.csv
# Yelp Data... Records: 8 Counter: 25  YelpDataZip_92342.csv
# Yelp Data... Records: 175 Counter: 26  YelpDataZip_91105.csv
# Yelp Data... Records: 158 Counter: 27  YelpDataZip_92801.csv
# Yelp Data... Records: 52 Counter: 28  YelpDataZip_91307.csv
# Yelp Data... Records: 116 Counter: 29  YelpDataZip_90804.csv
# Yelp Data... Records: 37 Counter: 30  YelpDataZip_90623.csv
# Yelp Data... Records: 266 Counter: 31  YelpDataZip_92008.csv
# Yelp Data... Records: 1 Counter: 32  YelpDataZip_92544.csv
# Yelp Data... Records: 0 Counter: 33  YelpDataZip_92222.csv
# Yelp Data... Records: 0 Counter: 34  YelpDataZip_91716.csv
# Yelp Data... Records: 14 Counter: 35  YelpDataZip_90742.csv
# Yelp Data... Records: 0 Counter: 36  YelpDataZip_92814.csv
# Yelp Data... Records: 9 Counter: 37  YelpDataZip_92182.csv
# Yelp Data... Records: 0 Counter: 38  YelpDataZip_91110.csv
# Yelp Data... Records: 0 Counter: 39  YelpDataZip_92369.csv
# Yelp Data... Records: 74 Counter: 40  YelpDataZip_90032.csv
# Yelp Data... Records: 1 Counter: 41  YelpDataZip_92619.csv
# Yelp Data... Records: 5 Counter: 42  YelpDataZip_91066.csv
# Yelp Data... Records: 8 Counter: 43  YelpDataZip_92585.csv
# Yelp Data... Records: 127 Counter: 44  YelpDataZip_90621.csv
# Yelp Data... Records: 0 Counter: 45  YelpDataZip_92142.csv
# Yelp Data... Records: 147 Counter: 46  YelpDataZip_90033.csv
# Yelp Data... Records: 0 Counter: 47  YelpDataZip_92340.csv
# Yelp Data... Records: 0 Counter: 48  YelpDataZip_93005.csv
# Yelp Data... Records: 3 Counter: 49  YelpDataZip_92333.csv
# Yelp Data... Records: 1 Counter: 50  YelpDataZip_90083.csv
# Yelp Data... Records: 0 Counter: 51  YelpDataZip_91410.csv
# Yelp Data... Records: 33 Counter: 52  YelpDataZip_90732.csv
# Yelp Data... Records: 0 Counter: 53  YelpDataZip_92079.csv
# Yelp Data... Records: 75 Counter: 54  YelpDataZip_92284.csv
# Yelp Data... Records: 0 Counter: 55  YelpDataZip_90848.csv
# Yelp Data... Records: 35 Counter: 56  YelpDataZip_92093.csv
# Yelp Data... Records: 64 Counter: 57  YelpDataZip_91411.csv
# Yelp Data... Records: 0 Counter: 58  YelpDataZip_90096.csv
# Yelp Data... Records: 0 Counter: 59  YelpDataZip_92871.csv
# Yelp Data... Records: 81 Counter: 60  YelpDataZip_91607.csv
# Yelp Data... Records: 0 Counter: 61  YelpDataZip_91175.csv
# Yelp Data... Records: 0 Counter: 62  YelpDataZip_90296.csv
# Yelp Data... Records: 67 Counter: 63  YelpDataZip_91361.csv
# Yelp Data... Records: 0 Counter: 64  YelpDataZip_92052.csv
# Yelp Data... Records: 7 Counter: 65  YelpDataZip_92250.csv
# Yelp Data... Records: 12 Counter: 66  YelpDataZip_92251.csv
# Yelp Data... Records: 0 Counter: 67  YelpDataZip_91758.csv
# Yelp Data... Records: 0 Counter: 68  YelpDataZip_92286.csv
# Yelp Data... Records: 0 Counter: 69  YelpDataZip_90888.csv
# Yelp Data... Records: 0 Counter: 70  YelpDataZip_92899.csv
# Yelp Data... Records: 13 Counter: 71  YelpDataZip_90056.csv
# Yelp Data... Records: 0 Counter: 72  YelpDataZip_90081.csv
# Yelp Data... Records: 142 Counter: 73  YelpDataZip_90254.csv
# Yelp Data... Records: 207 Counter: 74  YelpDataZip_93003.csv
# Yelp Data... Records: 0 Counter: 75  YelpDataZip_90091.csv
# Yelp Data... Records: 0 Counter: 76  YelpDataZip_91358.csv
# Yelp Data... Records: 0 Counter: 77  YelpDataZip_90734.csv
# Yelp Data... Records: 2 Counter: 78  YelpDataZip_90052.csv
# Yelp Data... Records: 55 Counter: 79  YelpDataZip_91210.csv
# Yelp Data... Records: 0 Counter: 80  YelpDataZip_91012.csv
# Yelp Data... Records: 1 Counter: 81  YelpDataZip_92268.csv
# Yelp Data... Records: 0 Counter: 82  YelpDataZip_91749.csv
# Yelp Data... Records: 0 Counter: 83  YelpDataZip_91365.csv
# Yelp Data... Records: 147 Counter: 84  YelpDataZip_91403.csv
# Yelp Data... Records: 0 Counter: 85  YelpDataZip_90053.csv
# Yelp Data... Records: 10 Counter: 86  YelpDataZip_92136.csv
# Yelp Data... Records: 0 Counter: 87  YelpDataZip_90084.csv
# Yelp Data... Records: 0 Counter: 88  YelpDataZip_90509.csv
# Yelp Data... Records: 0 Counter: 89  YelpDataZip_91617.csv
# Yelp Data... Records: 0 Counter: 90  YelpDataZip_91603.csv
# Yelp Data... Records: 1 Counter: 91  YelpDataZip_92652.csv
# Yelp Data... Records: 86 Counter: 92  YelpDataZip_92083.csv
# Yelp Data... Records: 14 Counter: 93  YelpDataZip_91978.csv
# Yelp Data... Records: 2 Counter: 94  YelpDataZip_92242.csv
# Yelp Data... Records: 230 Counter: 95  YelpDataZip_91776.csv
# Yelp Data... Records: 0 Counter: 96  YelpDataZip_92531.csv
# Yelp Data... Records: 110 Counter: 97  YelpDataZip_92860.csv
# Yelp Data... Records: 94 Counter: 98  YelpDataZip_91602.csv
# Yelp Data... Records: 0 Counter: 99  YelpDataZip_92323.csv
# Yelp Data... Records: 3 Counter: 100  YelpDataZip_90263.csv
# Yelp Data... Records: 55 Counter: 101  YelpDataZip_90713.csv
# Yelp Data... Records: 268 Counter: 102  YelpDataZip_92104.csv
# Yelp Data... Records: 0 Counter: 103  YelpDataZip_90075.csv
# Yelp Data... Records: 0 Counter: 104  YelpDataZip_92702.csv
# Yelp Data... Records: 0 Counter: 105  YelpDataZip_92515.csv
# Yelp Data... Records: 0 Counter: 106  YelpDataZip_91222.csv
# Yelp Data... Records: 0 Counter: 107  YelpDataZip_90074.csv
# Yelp Data... Records: 60 Counter: 108  YelpDataZip_90504.csv
# Yelp Data... Records: 72 Counter: 109  YelpDataZip_91803.csv
# Yelp Data... Records: 76 Counter: 110  YelpDataZip_90260.csv
# Yelp Data... Records: 0 Counter: 111  YelpDataZip_91618.csv
# Yelp Data... Records: 0 Counter: 112  YelpDataZip_91426.csv
# Yelp Data... Records: 1 Counter: 113  YelpDataZip_92517.csv
# Yelp Data... Records: 107 Counter: 114  YelpDataZip_92270.csv
# Yelp Data... Records: 98 Counter: 115  YelpDataZip_90301.csv
# Yelp Data... Records: 0 Counter: 116  YelpDataZip_91976.csv
# Yelp Data... Records: 0 Counter: 117  YelpDataZip_90671.csv
# Yelp Data... Records: 2 Counter: 118  YelpDataZip_91209.csv
# Yelp Data... Records: 0 Counter: 119  YelpDataZip_90659.csv
# Yelp Data... Records: 115 Counter: 120  YelpDataZip_90249.csv
# Yelp Data... Records: 0 Counter: 121  YelpDataZip_91609.csv
# Yelp Data... Records: 5 Counter: 122  YelpDataZip_92328.csv
# Yelp Data... Records: 0 Counter: 123  YelpDataZip_91386.csv
# Yelp Data... Records: 0 Counter: 124  YelpDataZip_91392.csv
# Yelp Data... Records: 108 Counter: 125  YelpDataZip_90067.csv
# Yelp Data... Records: 5 Counter: 126  YelpDataZip_90846.csv
# Yelp Data... Records: 14 Counter: 127  YelpDataZip_90305.csv
# Yelp Data... Records: 0 Counter: 128  YelpDataZip_92513.csv
# Yelp Data... Records: 69 Counter: 129  YelpDataZip_90304.csv
# Yelp Data... Records: 0 Counter: 130  YelpDataZip_92261.csv
# Yelp Data... Records: 0 Counter: 131  YelpDataZip_90310.csv
# Yelp Data... Records: 0 Counter: 132  YelpDataZip_91797.csv
# Yelp Data... Records: 0 Counter: 133  YelpDataZip_92711.csv
# Yelp Data... Records: 103 Counter: 134  YelpDataZip_91436.csv
# Yelp Data... Records: 60 Counter: 135  YelpDataZip_90270.csv
# Yelp Data... Records: 6 Counter: 136  YelpDataZip_92301.csv
# Yelp Data... Records: 0 Counter: 137  YelpDataZip_90264.csv
# Yelp Data... Records: 14 Counter: 138  YelpDataZip_92317.csv
# Yelp Data... Records: 70 Counter: 139  YelpDataZip_92673.csv
# Yelp Data... Records: 0 Counter: 140  YelpDataZip_90306.csv
# Yelp Data... Records: 1 Counter: 141  YelpDataZip_90312.csv
# Yelp Data... Records: 8 Counter: 142  YelpDataZip_92539.csv
# Yelp Data... Records: 0 Counter: 143  YelpDataZip_91031.csv
# Yelp Data... Records: 0 Counter: 144  YelpDataZip_90313.csv
# Yelp Data... Records: 0 Counter: 145  YelpDataZip_92074.csv
# Yelp Data... Records: 43 Counter: 146  YelpDataZip_90059.csv
# Yelp Data... Records: 190 Counter: 147  YelpDataZip_90703.csv
# Yelp Data... Records: 28 Counter: 148  YelpDataZip_92316.csv
# Yelp Data... Records: 204 Counter: 149  YelpDataZip_92832.csv
# Yelp Data... Records: 0 Counter: 150  YelpDataZip_91334.csv
# Yelp Data... Records: 61 Counter: 151  YelpDataZip_92173.csv
# Yelp Data... Records: 0 Counter: 152  YelpDataZip_91526.csv
# Yelp Data... Records: 29 Counter: 153  YelpDataZip_92210.csv
# Yelp Data... Records: 0 Counter: 154  YelpDataZip_92589.csv
# Yelp Data... Records: 5 Counter: 155  YelpDataZip_90639.csv
# Yelp Data... Records: 1 Counter: 156  YelpDataZip_90822.csv
# Yelp Data... Records: 0 Counter: 157  YelpDataZip_92172.csv
# Yelp Data... Records: 0 Counter: 158  YelpDataZip_92166.csv
# Yelp Data... Records: 1 Counter: 159  YelpDataZip_92364.csv
# Yelp Data... Records: 0 Counter: 160  YelpDataZip_91109.csv
# Yelp Data... Records: 0 Counter: 161  YelpDataZip_92158.csv
# Yelp Data... Records: 0 Counter: 162  YelpDataZip_92616.csv
# Yelp Data... Records: 2 Counter: 163  YelpDataZip_92548.csv
# Yelp Data... Records: 0 Counter: 164  YelpDataZip_90410.csv
# Yelp Data... Records: 36 Counter: 165  YelpDataZip_92549.csv
# Yelp Data... Records: 75 Counter: 166  YelpDataZip_91915.csv
# Yelp Data... Records: 2 Counter: 167  YelpDataZip_92039.csv
# Yelp Data... Records: 0 Counter: 168  YelpDataZip_90835.csv
# Yelp Data... Records: 422 Counter: 169  YelpDataZip_90028.csv
# Yelp Data... Records: 0 Counter: 170  YelpDataZip_91322.csv
# Yelp Data... Records: 21 Counter: 171  YelpDataZip_92401.csv
# Yelp Data... Records: 140 Counter: 172  YelpDataZip_92373.csv
# Yelp Data... Records: 0 Counter: 173  YelpDataZip_91118.csv
# Yelp Data... Records: 10 Counter: 174  YelpDataZip_92377.csv
# Yelp Data... Records: 1 Counter: 175  YelpDataZip_91124.csv
# Yelp Data... Records: 0 Counter: 176  YelpDataZip_92834.csv
# Yelp Data... Records: 0 Counter: 177  YelpDataZip_92149.csv
# Yelp Data... Records: 159 Counter: 178  YelpDataZip_90038.csv
# Yelp Data... Records: 3 Counter: 179  YelpDataZip_91905.csv
# Yelp Data... Records: 42 Counter: 180  YelpDataZip_92203.csv
# Yelp Data... Records: 0 Counter: 181  YelpDataZip_91051.csv
# Yelp Data... Records: 23 Counter: 182  YelpDataZip_91737.csv
# Yelp Data... Records: 0 Counter: 183  YelpDataZip_92160.csv
# Yelp Data... Records: 0 Counter: 184  YelpDataZip_91131.csv
# Yelp Data... Records: 77 Counter: 185  YelpDataZip_90211.csv
# Yelp Data... Records: 0 Counter: 186  YelpDataZip_91523.csv
# Yelp Data... Records: 0 Counter: 187  YelpDataZip_92572.csv
# Yelp Data... Records: 0 Counter: 188  YelpDataZip_91046.csv
# Yelp Data... Records: 37 Counter: 189  YelpDataZip_91913.csv
# Yelp Data... Records: 6 Counter: 190  YelpDataZip_91330.csv
# Yelp Data... Records: 243 Counter: 191  YelpDataZip_90006.csv
# Yelp Data... Records: 1 Counter: 192  YelpDataZip_92163.csv
# Yelp Data... Records: 0 Counter: 193  YelpDataZip_92605.csv
# Yelp Data... Records: 0 Counter: 194  YelpDataZip_92836.csv
# Yelp Data... Records: 0 Counter: 195  YelpDataZip_91126.csv
# Yelp Data... Records: 0 Counter: 196  YelpDataZip_92413.csv
# Yelp Data... Records: 76 Counter: 197  YelpDataZip_92407.csv
#
# Start summary of Yelp data...
# Completed summarizing the data  ./AnalysisData/summarizedYelpData.csv

# %%
#- Preview Summarized Data
print(summarizedYelpData_df.shape)

pd.set_option('display.max_columns', 500)
summarizedYelpData_df.head()
# Out:
# (107, 39)
#    Zipcode  GF_Total  GF_Price_1  GF_Price_2  GF_Price_3  GF_Price_4  \
# 0    90006        26           7          15           2           0
# 1    90028       135          37          77          16           1
# 2    90032         7           3           4           0           0
# 3    90033         7           2           5           0           0
# 4    90035        43           5          35           1           0
#
#    GF_Price_0  GF_Rating_10  GF_Rating_15  GF_Rating_20  GF_Rating_25  \
# 0           0             0             1             1             0
# 1           0             0             0             0             4
# 2           0             0             1             0             0
# 3           0             0             0             0             0
# 4           0             0             0             2             0
#
#    GF_Rating_30  GF_Rating_35  GF_Rating_40  GF_Rating_45  GF_Rating_50  \
# 0             0             6            13             4             1
# 1             9            38            55            27             2
# 2             0             1             2             2             1
# 3             0             0             3             3             1
# 4             2            12            14            11             2
#
#    GF_Price_Mean  GF_Rating_Mean  GF_Price_Std  GF_Rating_Std  ALL_Total  \
# 0       1.791667        3.826923      0.588230       0.720310        217
# 1       1.854962        3.862963      0.645959       0.501601        287
# 2       1.571429        3.857143      0.534522       1.144344         67
# 3       1.714286        4.357143      0.487950       0.377964        140
# 4       1.902439        3.895349      0.374492       0.641410        107
#
#    ALL_Price_1  ALL_Price_2  ALL_Price_3  ALL_Price_4  ALL_Price_0  \
# 0           98           76            4            0            0
# 1          111          130           20            2            0
# 2           49           10            0            0            0
# 3           86           26            1            0            0
# 4           28           64            3            1            0
#
#    ALL_Rating_10  ALL_Rating_15  ALL_Rating_20  ALL_Rating_25  ALL_Rating_30  \
# 0              4              7              8             12             20
# 1              2              4             16             20             34
# 2              2              3              3              3              3
# 3              1              1              9              7             15
# 4              0              4              3              7             10
#
#    ALL_Rating_35  ALL_Rating_40  ALL_Rating_45  ALL_Rating_50  ALL_Price_Mean  \
# 0             47             68             34             17        1.471910
# 1             73             83             46              9        1.669202
# 2             10             16             17             10        1.169492
# 3             17             32             37             21        1.247788
# 4             23             33             19              8        1.760417
#
#    ALL_Rating_Mean  ALL_Price_Std  ALL_Rating_Std
# 0         3.663594       0.543890        0.890907
# 1         3.594077       0.648605        0.787711
# 2         3.798507       0.378406        1.048302
# 3         3.871429       0.453773        0.906355
# 4         3.714953       0.557150        0.827340

# %%
#- Preview Yelp Data
print(yelpData_df.shape)

yelpData_df.head()
# Out:
# (6618, 10)
#   Unnamed: 0                      ID                        Name Zipcode  \
# 0          0  r5_pdXxKe6XEh3m15nSpxg  Nonna's Italian Restaurant   92407
# 1          1  oagIREcZKztHsyWgKAmiDg           Yang Noodle House   92407
# 2          2  TjUj2qJectQo6FjOEU9h4w           Rock N Roll Sushi   92407
# 3          3  LI2r9n8vqCWQE6lx2TwUKw            Baguette Express   92407
# 4          4  WUChRoWrYmLvapthpRBVAg                   Don Roman   92407
#
#     Latitude   Longitude Price  Rating IsGlutenFree  PriceNum
# 0  34.175171 -117.330432     $     4.5            1       1.0
# 1  34.188532 -117.356811    $$     4.5            1       2.0
# 2  34.177175 -117.330335    $$     3.5            1       2.0
# 3  34.175739 -117.330994     $     4.0            1       1.0
# 4  34.162861 -117.304994     $     4.5            1       1.0
